# %%
import os
import pandas as pd
import numpy as np
from os.path import join, exists

# %%
def parse_speaker_list(file_path):
    if not exists(file_path):
        print("File not found at {}".format(file_path))
    else:
        info = {}
        with open(file_path, "r") as f:
            lines = f.read().splitlines()
        for line in lines:
            entry = line.split()
            lang_code = entry[0]
            info[lang_code] = []
            for i in range(1, len(entry)):
                info[lang_code].append(entry[i].strip())
        return info
    
def get_stats(lang):
    csv_path = join("/home", "paul", "language-ident-from-speech", "gp_info", lang + ".csv")
    if exists(csv_path):
        return pd.read_csv(csv_path)
    else:
        print("CSV file not found at: {}".format(csv_path))
        
def get_speaker_lists():
    conf_dir = join("/home", "paul", "language-ident-from-speech", "gp-xvectors-recipe", "conf")
    train_speakers = parse_speaker_list(join(conf_dir, "train_spk.list"))
    enroll_speakers = parse_speaker_list(join(conf_dir, "enroll_spk.list"))
    eval_speakers = parse_speaker_list(join(conf_dir, "eval_spk.list"))
    test_speakers = parse_speaker_list(join(conf_dir, "test_spk.list"))
    return train_speakers, enroll_speakers, eval_speakers, test_speakers

def get_lang_code(lang):
    with open(join("/home", "paul", "language-ident-from-speech", "gp-xvectors-recipe", "conf", "lang_codes.txt"), "r") as f:
        lines = f.read().splitlines()
    for line in lines:
        entry = line.split()
        if entry[1] == lang:
            return entry[0]
        
def filter_df(df, speakers):
    return df[df.spk_id.isin(speakers)]

def print_stats(lang, dataset):
    train_speakers, enroll_speakers, eval_speakers, test_speakers = get_speaker_lists()
    lang_df = get_stats(lang)
    lang_code = get_lang_code(lang)
    lang_tr_df = filter_df(lang_df, train_speakers[lang_code])
    lang_eval_df = filter_df(lang_df, eval_speakers[lang_code])
    lang_enroll_df = filter_df(lang_df, enroll_speakers[lang_code])
    lang_test_df = filter_df(lang_df, test_speakers[lang_code])
    if dataset == "all":
        print_df_stats(lang_df, lang, "All")
    elif dataset == "train":
        print_df_stats(lang_tr_df, lang, "Training")
    elif dataset == "enroll":
        print_df_stats(lang_enroll_df, lang, "Enrollment")
    elif dataset == "eval":
        print_df_stats(lang_eval_df, lang, "Evaluation")
    elif dataset == "test":
        print_df_stats(lang_test_df, lang, "Testing")
    else:
        print("Unknown dataset option {}".format(dataset))
        
def print_df_stats(df, lang, name):
    age = str(round(df["age"].mean(),2))
    age_err = str(round(df["age"].std(ddof=0), 1))
    print("*"*30)
    print(name + " data for " + lang + " stats:")
    print("Total speakers")
    print(len(df))
    print("Genders")
    print(df["gender"].value_counts())
    print("Dialects:")
    print(df["dialect"].value_counts())
    print("Age")
    print("Have speaker data for:")
    print(df["age"].count())
    print(age + "+\-" + age_err)

# %%
pd.set_option("display.precision", 3)
    
train_speakers, enroll_speakers, eval_speakers, test_speakers = get_speaker_lists()
ar_df = get_stats("Arabic")
lang_code = get_lang_code("Arabic")
ar_tr = filter_df(ar_df, train_speakers[lang_code])

# %%
ref = [("Arabic", 0), ("Bulgarian", 1), ("Chinese-Shanghai", 2),
       ("Croatian", 3), ("Czech", 4), ("French", 5), ("German", 6),
       ("Japanese", 7), ("Korean", 8), ("Mandarin", 9), ("Polish", 10),
       ("Portuguese", 11), ("Russian", 12), ("Spanish", 13),
       ("Swedish", 14), ("Thai", 15), ("Turkish", 16),
       ("Vietnamese", 17)]

for i in range(18):
    print_stats(ref[i][0], "test")
# Out:
# ******************************
# Testing data for Arabic stats:
# Total speakers
# 7
# Genders
# female    5
# male      2
# Name: gender, dtype: int64
# Dialects:
# Tunisian    7
# Name: dialect, dtype: int64
# Age
# Have speaker data for:
# 7
# 27.0+\-9.1
# ******************************
# Testing data for Bulgarian stats:
# Total speakers
# 7
# Genders
# female    5
# male      2
# Name: gender, dtype: int64
# Dialects:
# no    7
# Name: dialect, dtype: int64
# Age
# Have speaker data for:
# 7
# 23.14+\-5.5
# ******************************
# Testing data for Chinese-Shanghai stats:
# Total speakers
# 4
# Genders
# female    3
# male      1
# Name: gender, dtype: int64
# Dialects:
# SH    2
# Name: dialect, dtype: int64
# Age
# Have speaker data for:
# 4
# 42.0+\-10.5
# ******************************
# Testing data for Croatian stats:
# Total speakers
# 10
# Genders
# female    6
# male      4
# Name: gender, dtype: int64
# Dialects:
# Bosnian              5
# Zagreb dialect       3
# Standard Croatian    2
# Name: dialect, dtype: int64
# Age
# Have speaker data for:
# 10
# 28.1+\-9.4
# ******************************
# Testing data for Czech stats:
# Total speakers
# 10
# Genders
# female    5
# male      5
# Name: gender, dtype: int64
# Dialects:
# common Czech    10
# Name: dialect, dtype: int64
# Age
# Have speaker data for:
# 10
# 27.6+\-16.1
# ******************************
# Testing data for French stats:
# Total speakers
# 8
# Genders
# male      4
# female    4
# Name: gender, dtype: int64
# Dialects:
# Series([], Name: dialect, dtype: int64)
# Age
# Have speaker data for:
# 8
# 32.25+\-11.4
# ******************************
# Testing data for German stats:
# Total speakers
# 6
# Genders
# male      4
# female    2
# Name: gender, dtype: int64
# Dialects:
# Series([], Name: dialect, dtype: int64)
# Age
# Have speaker data for:
# 0
# nan+\-nan
# ******************************
# Testing data for Japanese stats:
# Total speakers
# 6
# Genders
# male      5
# female    1
# Name: gender, dtype: int64
# Dialects:
# Standard Japanese    2
# Osaka-ben            1
# Tochigi-ben          1
# Hokaido-ben          1
# Kansai-ben           1
# Name: dialect, dtype: int64
# Age
# Have speaker data for:
# 6
# 24.83+\-5.6
# ******************************
# Testing data for Korean stats:
# Total speakers
# 10
# Genders
# female    5
# male      5
# Name: gender, dtype: int64
# Dialects:
# Seoul         4
# Chunbuk       1
# Chungchung    1
# Kyungsang     1
# Chonnam       1
# Name: dialect, dtype: int64
# Age
# Have speaker data for:
# 10
# 25.6+\-4.3
# ******************************
# Testing data for Mandarin stats:
# Total speakers
# 10
# Genders
# female    5
# male      5
# Name: gender, dtype: int64
# Dialects:
# Standard Chinese    8
# Ketong              1
# Jianxi              1
# Name: dialect, dtype: int64
# Age
# Have speaker data for:
# 10
# 19.9+\-0.7
# ******************************
# Testing data for Polish stats:
# Total speakers
# 10
# Genders
# female    4
# Name: gender, dtype: int64
# Dialects:
# Series([], Name: dialect, dtype: int64)
# Age
# Have speaker data for:
# 4
# 35.0+\-12.2
# ******************************
# Testing data for Portuguese stats:
# Total speakers
# 7
# Genders
# male      4
# female    3
# Name: gender, dtype: int64
# Dialects:
# Paulista    6
# Sulista     1
# Name: dialect, dtype: int64
# Age
# Have speaker data for:
# 7
# 25.57+\-12.8
# ******************************
# Testing data for Russian stats:
# Total speakers
# 10
# Genders
# female    6
# male      4
# Name: gender, dtype: int64
# Dialects:
# weissrussisch      3
# kaum zu spueren    1
# Name: dialect, dtype: int64
# Age
# Have speaker data for:
# 10
# 35.7+\-10.7
# ******************************
# Testing data for Spanish stats:
# Total speakers
# 8
# Genders
# female    4
# male      4
# Name: gender, dtype: int64
# Dialects:
# Tico            6
# Guanacasteco    2
# Name: dialect, dtype: int64
# Age
# Have speaker data for:
# 8
# 21.88+\-1.5
# ******************************
# Testing data for Swedish stats:
# Total speakers
# 10
# Genders
# female    5
# male      5
# Name: gender, dtype: int64
# Dialects:
# Smaalaendska    5
# Oelaendska      3
# Norrlaendska    1
# Stockholmska    1
# Name: dialect, dtype: int64
# Age
# Have speaker data for:
# 10
# 35.0+\-15.8
# ******************************
# Testing data for Thai stats:
# Total speakers
# 8
# Genders
# female    6
# male      2
# Name: gender, dtype: int64
# Dialects:
# middle    8
# Name: dialect, dtype: int64
# Age
# Have speaker data for:
# 8
# 23.12+\-0.8
# ******************************
# Testing data for Turkish stats:
# Total speakers
# 10
# Genders
# female    7
# male      3
# Name: gender, dtype: int64
# Dialects:
# Standard Turkish    8
# Anatolian           2
# Name: dialect, dtype: int64
# Age
# Have speaker data for:
# 10
# 28.4+\-11.8
# ******************************
# Testing data for Vietnamese stats:
# Total speakers
# 5
# Genders
# male      3
# female    2
# Name: gender, dtype: int64
# Dialects:
# Southern Vietnam    4
# Northern Vietnam    1
# Name: dialect, dtype: int64
# Age
# Have speaker data for:
# 5
# 20.8+\-2.2
