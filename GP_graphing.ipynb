# %%
import os
import pandas as pd
import numpy as np
from os.path import join, exists

# %%
def parse_speaker_list(file_path):
    if not exists(file_path):
        print("File not found at {}".format(file_path))
    else:
        info = {}
        with open(file_path, "r") as f:
            lines = f.read().splitlines()
        for line in lines:
            entry = line.split()
            lang_code = entry[0]
            info[lang_code] = []
            for i in range(1, len(entry)):
                info[lang_code].append(entry[i].strip())
        return info
    
def get_stats(lang):
    csv_path = join("/home", "paul", "language-ident-from-speech", "gp_info", lang + ".csv")
    if exists(csv_path):
        return pd.read_csv(csv_path)
    else:
        print("CSV file not found at: {}".format(csv_path))
        
def get_speaker_lists():
    conf_dir = join("/home", "paul", "language-ident-from-speech", "gp-xvectors-recipe", "conf")
    train_speakers = parse_speaker_list(join(conf_dir, "train_spk.list"))
    enroll_speakers = parse_speaker_list(join(conf_dir, "enroll_spk.list"))
    eval_speakers = parse_speaker_list(join(conf_dir, "eval_spk.list"))
    test_speakers = parse_speaker_list(join(conf_dir, "test_spk.list"))
    return train_speakers, enroll_speakers, eval_speakers, test_speakers

def get_lang_code(lang):
    with open(join("/home", "paul", "language-ident-from-speech", "gp-xvectors-recipe", "conf", "lang_codes.txt"), "r") as f:
        lines = f.read().splitlines()
    for line in lines:
        entry = line.split()
        if entry[1] == lang:
            return entry[0]
        
def filter_df(df, speakers):
    return df[df.spk_id.isin(speakers)]

def print_stats(lang, dataset):
    train_speakers, enroll_speakers, eval_speakers, test_speakers = get_speaker_lists()
    lang_df = get_stats(lang)
    lang_code = get_lang_code(lang)
    lang_tr_df = filter_df(lang_df, train_speakers[lang_code])
    lang_eval_df = filter_df(lang_df, eval_speakers[lang_code])
    lang_enroll_df = filter_df(lang_df, enroll_speakers[lang_code])
    lang_test_df = filter_df(lang_df, test_speakers[lang_code])
    if dataset == "all":
        print_df_stats(lang_df, lang, "All")
    elif dataset == "train":
        print_df_stats(lang_tr_df, lang, "Training")
    elif dataset == "enroll":
        print_df_stats(lang_enroll_df, lang, "Enrollment")
    elif dataset == "eval":
        print_df_stats(lang_eval_df, lang, "Evaluation")
    elif dataset == "test":
        print_df_stats(lang_test_df, lang, "Testing")
    else:
        print("Unknown dataset option {}".format(dataset))
        
def print_df_stats(df, lang, name):
    print("*"*30)
    print(name + " data for " + lang + " stats:")
    print("Total speakers")
    print(len(df))
    print("Genders")
    print(df["gender"].value_counts())
    print("Dialects:")
    print(df["dialect"].value_counts())
    print("Age")
    print("Have speaker data for:")
    print(df["age"].count())
    print(str(round(df["age"].mean(),3)) + "+\-" + str(round(df["age"].std(ddof=0), 3)))

# %%
pd.set_option("display.precision", 3)
    
train_speakers, enroll_speakers, eval_speakers, test_speakers = get_speaker_lists()
ar_df = get_stats("Arabic")
lang_code = get_lang_code("Arabic")
ar_tr = filter_df(ar_df, train_speakers[lang_code])

# %%
ref = [("Arabic", 0), ("Bulgarian", 1), ("Chinese-Shanghai", 2),
       ("Croatian", 3), ("Czech", 4), ("French", 5), ("German", 6),
       ("Japanese", 7), ("Korean", 8), ("Mandarin", 9), ("Polish", 10),
       ("Portuguese", 11), ("Russian", 12), ("Spanish", 13),
       ("Swedish", 14), ("Thai", 15), ("Turkish", 16),
       ("Vietnamese", 17)]

for i in range(18):
    print_stats(ref[i][0], "train")
# Out:
# ******************************
# Training data for Arabic stats:
# Total speakers
# 57
# Genders
# female    30
# male      27
# Name: gender, dtype: int64
# Dialects:
# Tunisian       45
# Palestinian    11
# Jordanian       1
# Name: dialect, dtype: int64
# Age
# Have speaker data for:
# 57
# 27.193+\-12.528
# ******************************
# Training data for Bulgarian stats:
# Total speakers
# 56
# Genders
# female    29
# male      27
# Name: gender, dtype: int64
# Dialects:
# no    53
# Name: dialect, dtype: int64
# Age
# Have speaker data for:
# 56
# 33.321+\-14.185
# ******************************
# Training data for Chinese-Shanghai stats:
# Total speakers
# 6
# Genders
# male      4
# female    2
# Name: gender, dtype: int64
# Dialects:
# SH    1
# Name: dialect, dtype: int64
# Age
# Have speaker data for:
# 6
# 41.333+\-6.774
# ******************************
# Training data for Croatian stats:
# Total speakers
# 63
# Genders
# female    41
# male      22
# Name: gender, dtype: int64
# Dialects:
# Bosnian                    36
# Zagreb dialect             12
# Standard Croatian           8
# Kajkav                      4
# Purgerian, street slang     1
# Northern Bosnian            1
# Shtokav                     1
# Name: dialect, dtype: int64
# Age
# Have speaker data for:
# 62
# 35.339+\-15.484
# ******************************
# Training data for Czech stats:
# Total speakers
# 72
# Genders
# male      41
# female    31
# Name: gender, dtype: int64
# Dialects:
# common Czech    72
# Name: dialect, dtype: int64
# Age
# Have speaker data for:
# 72
# 26.625+\-11.268
# ******************************
# Training data for French stats:
# Total speakers
# 74
# Genders
# female    38
# male      36
# Name: gender, dtype: int64
# Dialects:
# Series([], Name: dialect, dtype: int64)
# Age
# Have speaker data for:
# 72
# 32.153+\-12.02
# ******************************
# Training data for German stats:
# Total speakers
# 58
# Genders
# male      56
# female     2
# Name: gender, dtype: int64
# Dialects:
# Series([], Name: dialect, dtype: int64)
# Age
# Have speaker data for:
# 0
# nan+\-nan
# ******************************
# Training data for Japanese stats:
# Total speakers
# 119
# Genders
# male      87
# female    31
# Name: gender, dtype: int64
# Dialects:
# Standard Japanese                61
# TOKYO-ben                         5
# Kansai-ben                        4
# Osaka-ben                         3
# SAITAMA-ben                       3
# Fukushima-ben                     2
# Hiroshima-ben                     2
# Tosa-ben                          2
# Hakata-ben                        2
# Tohoku-ben                        2
# Ibaragi-ben                       2
# Okayama-ben                       2
# some Kansai-ben                   1
# HIROSHIMA-ben                     1
# Saga-ben                          1
# Yokohama-ben                      1
# Niigata-ben                       1
# KAGOSHIMA-ben                     1
# Totigi-ben                        1
# no dialect                        1
# Okinawa-ben                       1
# Standard Japanese (Kurumeben)     1
# CHIBA-ben                         1
# Sanin-ben                         1
# FUKUI-ben                         1
# Matsuyamaben,Fukuoka-ben          1
# Matsuyamaben,Osaka-ben            1
# Saitama-ben                       1
# Imaji-ben                         1
# Tochigi-ben                       1
# Kyusyu-ben                        1
# HUKUOKA-ben                       1
# Hakodate-ben                      1
# TOHOKU-ben                        1
# Nagaoka-ben                       1
# Miyazaki-ben                      1
# Yamagata-ben                      1
# some Toyama-ben                   1
# Name: dialect, dtype: int64
# Age
# Have speaker data for:
# 118
# 23.271+\-8.095
# ******************************
# Training data for Korean stats:
# Total speakers
# 70
# Genders
# female    35
# male      35
# Name: gender, dtype: int64
# Dialects:
# Seoul         28
# Chonnam       22
# Kyungsang      6
# Chunnam        4
# Kyongbu        1
# Kangwon        1
# Kyungki        1
# Chungchung     1
# Chungbuk       1
# Name: dialect, dtype: int64
# Age
# Have speaker data for:
# 69
# 25.565+\-4.918
# ******************************
# Training data for Mandarin stats:
# Total speakers
# 98
# Genders
# male      50
# female    48
# Name: gender, dtype: int64
# Dialects:
# Standard Chinese    18
# Hubei               17
# Kentong             13
# Hunan                7
# Wuhan                6
# Shandong             5
# Henan                5
# Anhui                3
# Ketong               3
# Jiangsu              3
# Chaozhou             3
# Schanghai            2
# Guizhou              2
# Hanzhong             1
# Xinjiang             1
# Sichuan              1
# Dongbei              1
# Nanjing              1
# Fujian               1
# Jiangzhe             1
# Shanxi               1
# Tianjin              1
# Zhejiang             1
# Name: dialect, dtype: int64
# Age
# Have speaker data for:
# 98
# 23.357+\-5.784
# ******************************
# Training data for Polish stats:
# Total speakers
# 69
# Genders
# male      9
# female    8
# Name: gender, dtype: int64
# Dialects:
# Series([], Name: dialect, dtype: int64)
# Age
# Have speaker data for:
# 17
# 35.412+\-9.69
# ******************************
# Training data for Portuguese stats:
# Total speakers
# 76
# Genders
# female    38
# male      38
# Name: gender, dtype: int64
# Dialects:
# Paulista          30
# Mineiro            8
# Nordestino         6
# Gaucho             4
# Sulista            4
# Carioca            3
# Paranaense         2
# Maranhaense        2
# Mato Grossense     1
# Goiano             1
# Brasiliense        1
# Paraibense         1
# Amazonense         1
# Name: dialect, dtype: int64
# Age
# Have speaker data for:
# 75
# 29.627+\-8.957
# ******************************
# Training data for Russian stats:
# Total speakers
# 84
# Genders
# male      48
# female    36
# Name: gender, dtype: int64
# Dialects:
# unbetonter "o" liest man immer als "o"    1
# weissrussisch                             1
# ja                                        1
# -?                                        1
# bestimmt aber welchen....                 1
# kaum zu merken                            1
# Name: dialect, dtype: int64
# Age
# Have speaker data for:
# 84
# 27.131+\-9.675
# ******************************
# Training data for Spanish stats:
# Total speakers
# 72
# Genders
# female    41
# male      31
# Name: gender, dtype: int64
# Dialects:
# Tico            65
# Limonense        1
# Guatemalteco     1
# Mexican          1
# Canario          1
# Uruguayo         1
# Colombiano       1
# Ecuadorian       1
# Name: dialect, dtype: int64
# Age
# Have speaker data for:
# 72
# 28.208+\-12.346
# ******************************
# Training data for Swedish stats:
# Total speakers
# 70
# Genders
# female    36
# male      34
# Name: gender, dtype: int64
# Dialects:
# Smaalaendska     28
# Goeteborgska     12
# Oelaendska        8
# Stockholmska      4
# Vaermlaendska     4
# Vaestgoetska      3
# Skaanska          2
# Soermlaendska     2
# Oestgoetska       1
# Blekingska        1
# Bohusmaal         1
# Hallaendska       1
# Norrlaendska      1
# Gotlaendska       1
# Uppsvenska        1
# Name: dialect, dtype: int64
# Age
# Have speaker data for:
# 70
# 31.643+\-13.666
# ******************************
# Training data for Thai stats:
# Total speakers
# 73
# Genders
# female    48
# male      21
# X          4
# Name: gender, dtype: int64
# Dialects:
# middle    40
# Middle    33
# Name: dialect, dtype: int64
# Age
# Have speaker data for:
# 73
# 20.26+\-1.544
# ******************************
# Training data for Turkish stats:
# Total speakers
# 69
# Genders
# female    49
# male      20
# Name: gender, dtype: int64
# Dialects:
# Standard Turkish    64
# Anatolian            5
# Name: dialect, dtype: int64
# Age
# Have speaker data for:
# 69
# 27.522+\-10.915
# ******************************
# Training data for Vietnamese stats:
# Total speakers
# 103
# Genders
# male      56
# female    45
# X          2
# Name: gender, dtype: int64
# Dialects:
# Southern Vietnam    55
# Northern Vietnam    48
# Name: dialect, dtype: int64
# Age
# Have speaker data for:
# 103
# 29.883+\-11.733

# %%
ar_tr.tail(10)
# Out:
#    language  spk_id  gender  age native_language      dialect
# 64   Arabic     106  female   20          Arabic  Palestinian
# 65   Arabic     107  female   23          Arabic  Palestinian
# 66   Arabic     108    male   23          Arabic  Palestinian
# 68   Arabic     110  female   19          Arabic  Palestinian
# 69   Arabic     111  female   25          Arabic  Palestinian
# 70   Arabic     112  female   41          Arabic  Palestinian
# 73   Arabic     134  female   24          Arabic  Palestinian
# 75   Arabic     136    male   66          Arabic  Palestinian
# 77   Arabic     164    male   36          Arabic  Palestinian
# 78   Arabic     165    male   23          Arabic     Tunisian
